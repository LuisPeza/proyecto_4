# %% [markdown]
# <h1>Tabla de Contenido <span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introducción" data-toc-modified-id="Introducción-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introducción</a></span></li><li><span><a href="#Diccionario-de-datos" data-toc-modified-id="Diccionario-de-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Diccionario de datos</a></span></li><li><span><a href="#Plan-de-solución" data-toc-modified-id="Plan-de-solución-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Plan de solución</a></span></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conclusiones</a></span></li><li><span><a href="#Plan-de-solución" data-toc-modified-id="Plan-de-solución-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Plan de solución</a></span></li><li><span><a href="#Encuentra-y-elimina-los-valores-duplicados-(y-describe-cómo-tomaste-tus-decisiones)." data-toc-modified-id="Encuentra-y-elimina-los-valores-duplicados-(y-describe-cómo-tomaste-tus-decisiones).-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).</a></span><ul class="toc-item"><li><span><a href="#orders-data-frame" data-toc-modified-id="orders-data-frame-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span><code>orders</code> data frame</a></span></li><li><span><a href="#products-data-frame" data-toc-modified-id="products-data-frame-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span><code>products</code> data frame</a></span></li><li><span><a href="#departments-data-frame" data-toc-modified-id="departments-data-frame-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span><code>departments</code> data frame</a></span></li><li><span><a href="#aisles-data-frame" data-toc-modified-id="aisles-data-frame-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span><code>aisles</code> data frame</a></span></li><li><span><a href="#order_products-data-frame" data-toc-modified-id="order_products-data-frame-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span><code>order_products</code> data frame</a></span></li></ul></li><li><span><a href="#Encuentra-y-elimina-los-valores-ausentes" data-toc-modified-id="Encuentra-y-elimina-los-valores-ausentes-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Encuentra y elimina los valores ausentes</a></span><ul class="toc-item"><li><span><a href="#products-data-frame" data-toc-modified-id="products-data-frame-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span><code>products</code> data frame</a></span></li><li><span><a href="#orders-data-frame" data-toc-modified-id="orders-data-frame-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span><code>orders</code> data frame</a></span></li><li><span><a href="#order_products-data-frame" data-toc-modified-id="order_products-data-frame-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span><code>order_products</code> data frame</a></span></li></ul></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Conclusiones</a></span><ul class="toc-item"><li><span><a href="#[A1]-Verifica-que-los-valores-sean-sensibles" data-toc-modified-id="[A1]-Verifica-que-los-valores-sean-sensibles-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>[A1] Verifica que los valores sean sensibles</a></span></li><li><span><a href="#[A2]-Para-cada-hora-del-día,-¿cuántas-personas-hacen-órdenes?" data-toc-modified-id="[A2]-Para-cada-hora-del-día,-¿cuántas-personas-hacen-órdenes?-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>[A2] Para cada hora del día, ¿cuántas personas hacen órdenes?</a></span></li><li><span><a href="#[A3]-¿Qué-día-de-la-semana-compran-víveres-las-personas?" data-toc-modified-id="[A3]-¿Qué-día-de-la-semana-compran-víveres-las-personas?-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>[A3] ¿Qué día de la semana compran víveres las personas?</a></span></li><li><span><a href="#[A4]-¿Cuánto-tiempo-esperan-las-personas-hasta-hacer-otro-pedido?-Comenta-sobre-los-valores-mínimos-y-máximos." data-toc-modified-id="[A4]-¿Cuánto-tiempo-esperan-las-personas-hasta-hacer-otro-pedido?-Comenta-sobre-los-valores-mínimos-y-máximos.-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>[A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.</a></span></li><li><span><a href="#[B1]-Diferencia-entre-miércoles-y-sábados-para--'order_hour_of_day'.-Traza-gráficos-de-barra-para-los-dos-días-y-describe-las-diferencias-que-veas." data-toc-modified-id="[B1]-Diferencia-entre-miércoles-y-sábados-para--'order_hour_of_day'.-Traza-gráficos-de-barra-para-los-dos-días-y-describe-las-diferencias-que-veas.-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>[B1] Diferencia entre miércoles y sábados para  <code>'order_hour_of_day'</code>. Traza gráficos de barra para los dos días y describe las diferencias que veas.</a></span></li><li><span><a href="#[B2]-¿Cuál-es-la-distribución-para-el-número-de-pedidos-por-cliente?" data-toc-modified-id="[B2]-¿Cuál-es-la-distribución-para-el-número-de-pedidos-por-cliente?-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>[B2] ¿Cuál es la distribución para el número de pedidos por cliente?</a></span></li><li><span><a href="#[B3]-¿Cuáles-son-los-20-productos-más-populares-(muestra-su-ID-y-nombre)?" data-toc-modified-id="[B3]-¿Cuáles-son-los-20-productos-más-populares-(muestra-su-ID-y-nombre)?-8.7"><span class="toc-item-num">8.7&nbsp;&nbsp;</span>[B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?</a></span></li><li><span><a href="#[C1]-¿Cuántos-artículos-compran-normalmente-las-personas-en-un-pedido?-¿Cómo-es-la-distribución?" data-toc-modified-id="[C1]-¿Cuántos-artículos-compran-normalmente-las-personas-en-un-pedido?-¿Cómo-es-la-distribución?-8.8"><span class="toc-item-num">8.8&nbsp;&nbsp;</span>[C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?</a></span></li><li><span><a href="#[C2]-¿Cuáles-son-los-20-principales-artículos-que-vuelven-a-pedirse-con-mayor-frecuencia-(muestra-sus-nombres-e-IDs-de-los-productos)?" data-toc-modified-id="[C2]-¿Cuáles-son-los-20-principales-artículos-que-vuelven-a-pedirse-con-mayor-frecuencia-(muestra-sus-nombres-e-IDs-de-los-productos)?-8.9"><span class="toc-item-num">8.9&nbsp;&nbsp;</span>[C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?</a></span></li><li><span><a href="#[C3]-Para-cada-producto,-¿cuál-es-la-proporción-de-las-veces-que-se-pide-y-que-se-vuelve-a-pedir?" data-toc-modified-id="[C3]-Para-cada-producto,-¿cuál-es-la-proporción-de-las-veces-que-se-pide-y-que-se-vuelve-a-pedir?-8.10"><span class="toc-item-num">8.10&nbsp;&nbsp;</span>[C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?</a></span></li><li><span><a href="#[C4]-Para-cada-cliente,-¿qué-proporción-de-sus-productos-ya-los-había-pedido?" data-toc-modified-id="[C4]-Para-cada-cliente,-¿qué-proporción-de-sus-productos-ya-los-había-pedido?-8.11"><span class="toc-item-num">8.11&nbsp;&nbsp;</span>[C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?</a></span></li><li><span><a href="#[C5]-¿Cuáles-son-los-20-principales-artículos-que-las-personas-ponen-primero-en-sus-carritos?" data-toc-modified-id="[C5]-¿Cuáles-son-los-20-principales-artículos-que-las-personas-ponen-primero-en-sus-carritos?-8.12"><span class="toc-item-num">8.12&nbsp;&nbsp;</span>[C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?</a></span></li><li><span><a href="#Conclusion-general-del-proyecto:" data-toc-modified-id="Conclusion-general-del-proyecto:-8.13"><span class="toc-item-num">8.13&nbsp;&nbsp;</span>Conclusion general del proyecto:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # ¡Hola Luis!
#
# Mi nombre es Ezequiel Ferrario, soy code reviewer en Tripleten y tengo el agrado de revisar el proyecto que entregaste.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo lo voy a hacer? Voy a leer detenidamente cada una de las implementaciones que has llevado a cabo para cumplir con lo solicitado. Verás los comentarios de esta forma:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si todo está perfecto.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberá hacer las correcciones. Es como una tarea de prueba al solicitar un trabajo: muchos pequeños errores pueden hacer que un candidato sea rechazado.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, muchas gracias por tus comentarios y la revisión.
# </div>
#
# ¡Empecemos!

# %% [markdown]
# -------------
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario  general #1</b> <a class="tocSkip"></a>
#
# Luis, has realizado un excelente proyecto donde abarcaste todos los puntos de muy buena manera.
#
# A nivel codigo fue muy buen trabajo con la exploracion inicial y mejor aun con los graficos.
#
#  Dejaste excelentes conclusiones y todas las extracciones fueron bien planteadas.
#
# Es asi que restan  minimos puntos por corregir.
#
# Espero tus correcciones, saludos.</div>
#
# ----------
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario general #2</b> <a class="tocSkip"></a>
#
# Luis, abarcaste absolutamente todas las correcciones de buena manera y es asi que finalizas un gran trabajo.
#
#   Quiero destacar la conclusion final que fue perfecta donde aportaste un gran resumen de lo realizado.
#
#   Por lo expuesto, este trabajo queda **Aprobado**.
#
#   Exitos en lo que viene, saludos.
# </div>
#
# ---

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# En este caso podes hacer una tabla de contenidos que este  linkeada a las secciones (al clickear debe llevarnos a esa seccion) de esta menera es mas facil desplazarse.
#
# Como consejo, si realizas bien todas las secciones (con su respectivo #) podes generarlo automáticamente desde jupyter lab. Para hacerlo, en la pestaña de herramientas de jupyter lab clickeas en el **botón de los puntos y barras**  (Table of contents) te generara automáticamente una tabla de contenidos linkeable y estética. A la **derecha** del seleccionador del tipo de celda (code/markdown)
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, perfecto.
# </div>

# %% [markdown]
# ## Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
# 1.- Primero se explorara los valores del datasets abriendolos directo
# 2.- Una vez revisado un poco los Datasets comenzamos el plan de accion, 1ero importamos las librerias que vamos a ocupar en este caso pandas, numpy y pyplot para hacer graficas.
# 3.- Importamos los 5 Datasets y le ponemos el parametro sep, para que quite los puntos y comas.
# 4.- Mandamos a llamar a info() para dar un vistazo de las columnas, numero de datos y valores ausentes de los datasets, solo se incluye show_counts=True en el info() del dataset order_products

# %%
# importar librerías
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
df_orders = pd.read_csv('/datasets/instacart_orders.csv', sep = ";")
df_products = pd.read_csv('/datasets/products.csv', sep = ";")
df_order_products = pd.read_csv('/datasets/order_products.csv', sep = ";")
df_aisles = pd.read_csv('/datasets/aisles.csv', sep = ";")
df_departments = pd.read_csv('/datasets/departments.csv', sep = ";")

# %%
# mostrar información del DataFrame
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# mostrar información del DataFrame
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# mostrar información del DataFrame
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# mostrar información del DataFrame
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# mostrar información del DataFrame
df_departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
# 1.- Se observa que los 5 Datasets estan delimitados por (punto y coma), se corrije usando sep =
# 2.- Se tienen valores perdidos en 3 DF estos estan en (Instacart, products y order_products)
# 3.- Se nota que existen 2 columnas que estan con el tipo de datos Float, pero tengo duda si dejarlo así o cambiarlo a Int, las dos columnas son (Days_since,add_to_cart)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buena exploracion inicial.
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
# 1.- Se verificaron los tipos de datos y al parecer todas las columnas ID son enteros, pero verique que hay 2 columnas days_since_prior y add_to_cart_order que son de tipo flotante veo que estas se pueden modificar a entero ya que no tienen decimales.
# 2.- Se encontraron valores ausentes en el DF instacart en la columna days_since, que es la columna donde se registra el numero de dias transcurridos desde que hizo un pedido, tambien hay valores ausentes en la columna add_to_cart que es el orden secuencial.
# 3.- Se encontraron duplicados en el dataset instacart.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
print(df_orders['order_id'].duplicated().sum())
# Out:
# 15

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
# Si aparecen 15 duplicados, son pedidos que por error se registraron dos veces ya que tiene la misma informacion en todas sus columnas.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
pedidos = df_orders[(df_orders['order_dow'] == 3) & (df_orders['order_hour_of_day'] ==2)]
print(pedidos['order_dow'].count())#Se cuentan los pedidos que se hicieron a ese dia y hora
# Out:
# 121

# %% [markdown]
# ¿Qué sugiere este resultado? Existen 121 registros de pedidos el dia miercoles a las 2 a.m

# %%
# Elimina los pedidos duplicados
df_orders.drop_duplicates(inplace=True)
df_orders.reset_index(drop=True,inplace=True) #Se resetea el indice tras la eliminacion de los duplicados

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Luego de eliminar los duplicados, recorda reiniciar el indice tras la eliminación. Ya que el índice queda desordenado, dificultando manipulaciones. Al reiniciarlo, se obtiene un índice ordenado y se conserva el original en una nueva columna, preservando la integridad y facilitando futuras referencias . Recorda luego utilizar el parametro drop en true ya que de lo contrario te quedara el indice anterior como columna.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bueno.
# </div>

# %%
# Vuelve a verificar si hay filas duplicadas
print(df_orders.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
print(df_orders['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. Si aparecen 15 duplicados, son pedidos que por error se registraron dos veces ya que tiene la misma informacion en todas sus columnas.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Bien limpiados estos duplicados.
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(df_products.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
print(df_products['department_id'].duplicated().sum())
# Out:
# 49673

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
df_products['product_name'] = df_products['product_name'].str.upper() # Convertimos los nombres a mayusculas
print(df_products['product_name'].duplicated().sum()) # Imprimimos si hay nombres duplicados de productos
# Out:
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
productos_no_faltantes = df_products.dropna(subset=['product_name']) #Guardamos en una variable la eliminacion de los valores faltantes
duplicados = productos_no_faltantes['product_name'].duplicated().sum() # verificamos si de nuevo hay duplicados en productos no faltantes
print(f"Número de productos duplicados (sin faltantes): {duplicados}") # Imprimos el resultado
# Out:
# Número de productos duplicados (sin faltantes): 104

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. En este DF de Productos se encontraron que hay 49,673 duplicados en la columna department_id, ya despues de convertir todos los nombres de productos a mayusculas en la columna product_name y encontramos que hay 1361 nombres de productos duplicados. Al final revisamos si hay nombres duplicados de productos no faltantes y encontramos 104 de la columna product_name.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien.
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(df_departments.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de productos
print(df_departments['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# No se encontraron valores duplicados en el DF departments ya que solo tenemos 2 columnas con 20 datos y estos pueden ser observados completados por los pocos datos que son.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(df_aisles.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
print(df_aisles['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# No se contraron valores duplicados en este DF

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(df_order_products.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
print(df_order_products['order_id'].duplicated().sum())
# Out:
# 4094961

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.En este DF se encontraron duplicados en varias columnas como por ejemplo en la columna order_id este puede tener justificacion ya que ese mismo pedido pudo tener varias aristas de ser agregado al carrito

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente seccion.
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
print(df_products['product_name'].isna().sum())
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Existen 1258 valores ausentes en la columna ProductName

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
print(df_products[df_products['aisle_id'] == 100])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Si los valores ausentes estan determinados por el ID 100 ya que ese ID 100 no tiene nombre de pasillo.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
print(df_products[df_products['department_id'] == 21])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Si ya que ese departamento con ese ID 21 no tiene nombre por eso aparece vacio el nombre de producto

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
print(df_products[(df_products['aisle_id'] == 100)&(df_products['department_id'] ==21)])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Ya con el filtro de ambas condiciones Pasillo con ID 100 y departamento con ID 21 vemos que el nombre del producto sigue ausente.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df_products['product_name'].fillna('unknown',inplace=True)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. Se uso el metodo fillna() para reemplazar los valores ausentes de la columna product_name

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bueno.
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print(df_orders.isna().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
no_primero = df_orders[df_orders['order_number']>1]
no_primero = no_primero.isna().sum()
print(no_primero)
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. Hay valores ausentes solo en la columna days_since y al parecer no hay valores ausentes fuera del primer pedido del cliente

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente entendiendo la naturaleza de estos nulos.
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(df_order_products.isna().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
minimo = df_order_products['add_to_cart_order'].min()
print('El valor minimo de la columna add_to_cart es:',minimo)

maximo = df_order_products['add_to_cart_order'].max()
print('El valor maximo de la columna add_to_cart es:',maximo)
# Out:
# El valor minimo de la columna add_to_cart es: 1.0
# El valor maximo de la columna add_to_cart es: 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. El valor minimo debe ser 1 ya que es el primer articulo que se agrega al carrito el valor maximo es el 64

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
ids_pedidos = df_order_products[df_order_products['add_to_cart_order'].isna()]['order_id'].unique()
print(ids_pedidos)
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
ids_pedidos = df_order_products[df_order_products['add_to_cart_order'].isna()]['order_id'].unique()
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
conteo_productos = df_order_products.groupby('order_id')['product_id'].count()
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
conteo_productos_ausentes = conteo_productos[conteo_productos.index.isin(ids_pedidos)]
min_products = conteo_productos_ausentes.min()
print('valor minimo del conteo es:',min_products)
print('Todos los pedidos con valores ausentes tienen mas de 64 productos.?',min_products >65)
# Out:
# valor minimo del conteo es: 65
# Todos los pedidos con valores ausentes tienen mas de 64 productos.? False

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. El valor minimo fue de 65 y es falso que los valores ausentes tienen mas de 64 productos

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].fillna(999).astype(int)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. Se reemplazaron los valores con el metodo fillna por 999 y con astype(int) se convierte la columna a enteros

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¿Por que crees que el maximo de `add_to_cart_order` se detiene en 64? ¿No crees que es un valor muy arbitrario?</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Puede ser que este limitado el programa para evitar que el procesamiento de datos sea lento, o por alguna razon sacaron este promedio de compras que puede llegar hacer el usuario conforme a datos previos de compras.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, en este caso es muy probable que se haya almacenado como int64 por lo que se limito a solo ese numero -como maximo-, comentarle este tipo de problemas al cliente hara que nuestros datos sean mas completos.</div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos. Se encontraron varios valores ausentes y duplicados en varios DF despues de encontrarlos se eliminaron los valores ausentes y en otros casos se reemplazaron con palabras como unknows y 999, ademas de esto se hicieron algunas agrupaciones de informacion para obtener algunos datos especificos y se utilizaron los operadores logicos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buenas conclusiones.
#
# </div>

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
hora_dia = df_orders[(df_orders['order_hour_of_day'] >=0) & (df_orders['order_hour_of_day'] <=23)]

# %%
dia_semana = df_orders[(df_orders['order_dow'] >= 0)&(df_orders['order_dow'] <= 6)]

# %% [markdown]
# Escribe aquí tus conclusiones Se identifica que los valores estan correctos no existe algun otro numero fuera de esos rangos se encuentran entre el dia de la semana y en la hora correcta.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
hora_dia['order_hour_of_day'].value_counts().sort_index().plot(
    kind='bar', 
    figsize=(12, 6))
plt.title('Número de pedidos por hora del día')
plt.xlabel('Hora del día')
plt.ylabel('Número de pedidos')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones: Se nota que la gente hace sus compras a las 10,11 am y por la tarde 15 y 16 hrs. Sera que tienen mas tiempo para hacer sus pedidos despues de realizar sus labores.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bueno.
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
dia_semana['order_dow'].value_counts().sort_index().plot(
    kind='bar', 
    figsize=(10, 6))
plt.title('Dia de la semana que hacen sus compras')
plt.xlabel('Dia de la semana')
plt.ylabel('Numero de pedidos')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones: Tiene alta demanda el domingo para realizar sus compras y el lunes tambien es un buen dia para hacer sus compras. Con lo de viveres confunden.? Pense que tenia que ver un producto que tuviera viveres.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta muy bien, con los viveres se refiere a los productos en general,  la extraccion es perfecta.
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
df_orders['days_since_prior_order'].value_counts().sort_index().plot(
    kind='bar', figsize=(12, 6))
plt.title('Tiempo de espera para hacer otro pedido')
plt.xlabel('Dias transcurridos')
plt.ylabel('Numero de pedido')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones: Observando el grafico tenemos que el valor minimo es 0 para que vuelva a realizar una compra y el valor maximo es 30. Será que se esperan a comprar hasta el otro mes una vez que les haya caido el deposito de nomina.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen grafico.
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
miercoles = df_orders[df_orders['order_dow'] == 3]
sabado = df_orders[df_orders['order_dow'] == 6]

miercoles['order_hour_of_day'].plot(                            
    kind='hist',
    y = 'order_dow',
    figsize=(10, 6))
sabado['order_hour_of_day'].plot(kind='hist',
                                 alpha = 0.6,grid=True,
)
plt.title("Diferencia entre miercoles y sabados para Hora del dia")
plt.xlabel('Hora del dia')
plt.ylabel('Numero de pedidos')
plt.legend(['Miercoles','sabado'])

plt.show()

# %%
miercoles = df_orders[df_orders['order_dow'] == 3]
miercoles['order_hour_of_day'].plot(                            
    kind='hist',
    y = 'order_dow',
    color = 'green',grid=True,
    figsize=(10, 6))

plt.title("Visualización de solo el dia miercoles para hora del dia")
plt.xlabel('Hora del dia')
plt.ylabel('Numero de pedidos')
plt.show()

# %%
sabado = df_orders[df_orders['order_dow'] == 6]
sabado['order_hour_of_day'].plot(                            
    kind='hist',
    y = 'order_dow',
    color = 'blue', grid=True,
    figsize=(10, 6))

plt.title("Visualización de solo el dia sabado para hora del dia")
plt.xlabel('Hora del dia')
plt.ylabel('Numero de pedidos')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones. Ambos dias de la semana miercoles y sabado tienen compras parecidas se nota un ligero repunte los dias sabados a las 15 hrs al igual que el miercoles como a las 14 hrs tiene el repunte mas alto de la semana a esa hora. Sera que tienen un poco mas de tiempo para realizar compras a esas horas.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente, estan bien marcadas las diferencias con el primer grafico..
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
contar_pedidos = df_orders.groupby('user_id')['order_number'].count()
contar_pedidos.describe()
# Out:
# count    157437.000000
# mean          3.042182
# std           2.746842
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max          28.000000
# Name: order_number, dtype: float64

# %%
contar_pedidos = df_orders.groupby('user_id')['order_number'].count()

contar_pedidos.value_counts().sort_index().plot(                           
    kind='bar', ylim= [0,60000],
    alpha = 0.6,
    figsize=(10, 6))

plt.title("Distribucion para el número de pedidos por cliente")
plt.xlabel('Número de pedidos')
plt.ylabel('Numero de usuario')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones. Basandonos en el grafico se observa que el mayor porcentaje de numero de ordenes que hace cada cliente es 1 con aproximandamente arriba de 50000 clientes hace una orden seguido por 2 ordenes con arriba de 35000.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buena extraccion.
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
#Creando el grafico de los 20 productos mas populares
#Combinamos los df de order_products y products con product_id
combinado = df_order_products.merge(df_products, on='product_id', how='left')
#Solo nos quedamos con las 3 columnas que nos importan
combinado = combinado[['order_id','product_id','product_name']]
conteo = combinado['product_id'].value_counts()
df_conteo = pd.DataFrame({'product_id': conteo.index, 'conteo': conteo.values})

# %%
# Concatenar product_id y product_name para las etiquetas del eje x
etiquetas_eje_x = df_conteo_nombres['product_id'].astype(str) + ' - ' + df_conteo_nombres['product_name']
plt.figure(figsize=(12, 8))
plt.bar(etiquetas_eje_x,df_conteo_nombres['conteo'],alpha=0.6)
plt.title("Grafico que muestra los 20 productos mas populares")
plt.xlabel('Producto (ID - Nombre)')
plt.ylabel('Numero de pedido')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar los valores hara que la extraccion sea aun mas clara.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, buen complemento.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones: Tenemos que las Bananas, seguido de la bolsa de bananas Organica son los dos productos mas populares entre la gente que compra superando las 60000 ventas de este producto. Al parecer los 20 productos mas vendidos o populares son productos organicos, la gente consume esto por que según es mas saludable, no lo sé.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
#Contar los articulos por pedido
contar_articulos = df_order_products.groupby('order_id')['product_id'].count()
print('El promedio de articulos que compran por pedido es de: ',contar_articulos.mean())
# Out:
# El promedio de articulos que compran por pedido es de:  10.098983215049127

# %%
#Crear un histograma
contar_articulos.plot(kind='hist',figsize=(10,6),grid=True)

plt.title('Distribución de cuantos articulos compra la gente en un pedido')
plt.xlabel('# Pedidos')
plt.ylabel('# de clientes')
# Out:
# Text(0, 0.5, '# de clientes')

# %%
#Contar los articulos por pedido
contar_articulos = df_order_products.groupby('order_id')['product_id'].count()

#Grafico
contar_articulos.sort_index().head(30).plot(kind='hist',figsize=(10,6),grid=True)
plt.title('Distribución de cuantos articulos compran mostrando top 30')
plt.xlabel('# Pedidos')
plt.ylabel('# de clientes')
plt.show()

# %%
#Contar los articulos por pedido
contar_articulos = df_order_products.groupby('order_id')['product_id'].count()

#Grafico
contar_articulos.sort_index().head(40).plot(kind='hist',figsize=(10,6),grid=True)
plt.title('Distribución de cuantos articulos compran mostrando top 40')
plt.xlabel('# Pedidos')
plt.ylabel('# de clientes')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta perfecto el grafico, como consejo podrias graficar  (en otra celda) el top 30 o 40 para visualizar mejor los datos ya que a partir de alli practicamente no tenemos informacion.</div>

# %% [markdown]
# Escribe aquí tus conclusiones. Vemos que el promedio de articulos que compra la gente en un pedido es de 10 articulos. Creo que la gente aprovecha en comprar varios articulos, será que les conviene mejor pedidos varios articulos.
# Ya con la observacion de las dos graficas de top 30 y 40 se ve un poco mas la distribucion de los pedidos en segundo lugar la gente compra al rededor de 7 y 14 articulos y en tercer lugar se llevan de 2 o 3 articulos.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
# Combinar los DF Orders y Order_products para obtener la columna de product_name
ordersyproducts = df_orders.merge(df_order_products, on='order_id', how='right')
# Eliminar las columnas que no ocupamos
ordersyproducts.drop(['order_dow', 'order_hour_of_day', 'days_since_prior_order', 'add_to_cart_order'], axis='columns', inplace=True)
# Filtrar solo artículos que se han ordenado
reorden = ordersyproducts[ordersyproducts['reordered'] == 1]
# Combinar con df_products para obtener los nombres de los productos
reorden_con_nombres = reorden.merge(df_products, on='product_id', how='left')
# Contar la frecuencia de reordenamiento por producto
frecuencia_reorden = reorden_con_nombres['product_id'].value_counts().head(20)
# Obtener los nombres de los productos correspondientes a los IDs
nombres_productos = df_products[df_products['product_id'].isin(frecuencia_reorden.index)]

# %%
# Crear las etiquetas del eje X con product_id y product_name
etiquetas_eje_x = []
for id_producto in frecuencia_reorden.index:
    nombres = nombres_productos[nombres_productos['product_id'] == id_producto]['product_name'].values
    if len(nombres) > 0:
        etiquetas_eje_x.append(f"{id_producto} - {nombres[0]}")
    else:
        etiquetas_eje_x.append(f"{id_producto} - Producto no encontrado")  # Manejar el caso de producto no encontrado

# Crear la gráfica de barras
plt.figure(figsize=(16, 6))
plt.bar(etiquetas_eje_x, frecuencia_reorden.values, color='green')
plt.title('Los 20 artículos reordenados con mayor frecuencia')
plt.xlabel('Producto (ID - Nombre)')
plt.ylabel('Frecuencia de reordenamiento')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar los valores hara que la extraccion sea aun mas clara.</div>
#
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bien.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones: Las bananas al parecer tiene mucha demanda en si todos los productos organicos. Lo que se hizo en este ejercicio fue primero combinar los DF orders,order_products y product, se eliminaron las columnas que no ocupamos, se filtro los articulos que se han ordenado que si se han pedido con condicion == 1, se cuenta la frecuencia de reordenamiento por producto, se obtienen los productos que corresponden a su ID. Se crea una lista vacia y despues se genera un bucle for para obtener el nombre e id del producto que va en la etiqueta X del grafico. Al final se crea el grafico correspondiente.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
#Combinar los df products y order_products
combinado3 = df_products.merge(df_order_products, on='product_id', how='left')
#contamos las veces que se hace un pedido
repeticion_pedidos = combinado3.groupby('product_id')['order_id'].count()
#Calcular el número de repeticiones de pedido para cada producto
repeticiones = df_order_products[df_order_products['reordered'] == 1].groupby('product_id').size()

# %%
#Calcular la tasa de repetición
tasa_repeticion = (repeticiones / repeticion_pedidos).fillna(0)  # Llena NaN con 0
#Crear la tabla
tabla_repeticion = pd.DataFrame({'product_id': tasa_repeticion.index,'tasa_repeticion': tasa_repeticion.values})
# Combinar con df_products para obtener los nombres de los productos
tabla_repeticion = tabla_repeticion.merge(df_products, on='product_id', how='left')

# %%
# Reorganizar las columnas
tabla_repeticion = tabla_repeticion[['product_id', 'product_name', 'tasa_repeticion']]
#Imprimir tabla con las columnas product_id, product_name y proporcion en que sea vuelto a comprar
top_20_repeticion = tabla_repeticion.sort_values(by='tasa_repeticion', ascending=False).head(20)
print(top_20_repeticion)
# Out:
#        product_id                                       product_name  \
# 30643       30644                               ORGANIC FRENCH ROAST
# 7970         7971                             LAVENDER LOVE KOMBUCHA
# 17132       17133    LIMITED EDITION MILANO BANANA CHOCOLATE COOKIES
# 43497       43498                    SPARKLING FRENCH BERRY LEMONADE
# 24678       24679                              PETITE SMOKED OYSTERS
# 10465       10466                BABY NATURALS HEAD-TO-TOE BABY WASH
# 24664       24665        GO APPLE JUICE SWEETENED CRANBERRIES! DRIED
# 10462       10463                             SONIC ENERGY REFRESHED
# 43428       43429  ITALIAN-STYLE MUSHROOM-FLAVORED SPAGHETTI SAUC...
# 17183       17184                                 CHESTNUTS- ORGANIC
# 1970         1971                                 PLUM JASMINE WATER
# 10453       10454                          LIMITED EDITION ICE CREAM
# 7980         7981                      STRAWBERRY TARRAGON ICE CREAM
# ...

# %% [markdown]
# Escribe aquí tus conclusiones. La tasa de repeticion del pedido es solo de 1 vez por cada compra

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien.
#
# </div>

# %%
#Combinamos los DF df_orders y df_orders_products
combinado4 = df_orders.merge(df_order_products, on='order_id', how='left')
# Calcular la proporción de productos reordenados para cada cliente
def calcular_proporcion_reordenados(df_orders):
    total_productos = len(df_orders)
    productos_reordenados = df_orders['reordered'].sum()
    if total_productos == 0:
        return 0
    else:
        return productos_reordenados / total_productos
proporcion_reordenados_por_cliente = combinado4.groupby('user_id').apply(calcular_proporcion_reordenados)

# %%
# Crear la tabla resultante
tabla_proporcion_clientes = pd.DataFrame({
    'user_id': proporcion_reordenados_por_cliente.index,
    'proporcion_reordenados': proporcion_reordenados_por_cliente.values
})
# Imprimir la tabla
print(tabla_proporcion_clientes.head(20))
# Out:
#     user_id  proporcion_reordenados
# 0         2                0.038462
# 1         4                0.000000
# 2         5                0.666667
# 3         6                0.000000
# 4         7                0.928571
# 5        10                0.000000
# 6        11                0.187500
# 7        12                0.250000
# 8        13                0.565217
# 9        14                0.354839
# 10       15                0.538462
# 11       16                0.531250
# 12       17                0.716981
# 13       19                0.291667
# 14       20                0.000000
# 15       21                0.400000
# 16       22                1.000000
# 17       23                0.000000
# 18       24                0.500000
# 19       25                0.000000

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien la idea de plantear una funcion
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones: Como conclusion se tiene que la tasa de proporcion de un pedido que se vuelve a pedir es relativamente baja siendo casi 1 la proporcion. Lo que se realizo en este punto fue que se hizo de nuevo una combinación  de las tablas de orders y orders_products sobre order_id.
# Despues se aplico una función para poder calcular la proporcion de reodenamiento de la columna reordered se conto la longitud del df_orders, se creo una variable productos donde sumamos los productos reordenados, se hizo una condicion if si el total de los productos ==, regresa 0 si no , se aplica una operacion se divide los productos_reordenados entre total de productos.
# Se realiza un agrrupamiento por la columna user_id se aplica la funcion. Se crea un DF donde asignamos los datos solicitados user_id y la proporcion_reordenados. Se imprimen los primeros 20 valores de la tabla.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta perfecto lo realizado, conclui al respecto de este punto, podrias comentar que hiciste, que informacion nos aporta y porque puede ser interesante.
#
# Recorda que realizar una conclusion de cada punto agregara valor a nuestro tabajo de cara al cliente.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, buenas observaciones.
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
#Vamos a combinar los DF orders y order_products para obtener la columna de product_name
ordersyproducts = df_order_products.merge(df_products, on='product_id', how='right')
#Se filtran solo articulos que se han agregado primero al carrito
primeros_articulos = ordersyproducts[ordersyproducts['add_to_cart_order'] == 1]

# %%
# Cuenta la frecuencia de cada producto, agrupando por product_id y product_name
conteo_primeros_articulos = primeros_articulos.groupby(['product_id', 'product_name']).size().reset_index(name='veces_primer_articulo')
# Ordena los resultados por la frecuencia de forma descendente
conteo_primeros_articulos = conteo_primeros_articulos.sort_values(by='veces_primer_articulo', ascending=False)
# Obtener los 20 principales artículos
top_20 = conteo_primeros_articulos.head(20)
# Crear las etiquetas del eje X con product_id y product_name
etiquetas_eje_x = [f"{row['product_id']} - {row['product_name']}" for index, row in top_20.iterrows()]

# %%
#Mostrando el grafico donde el eje X mostramos el nombre del producto y en el eje Y el numero de veces que pone en primero el carrito

plt.bar(etiquetas_eje_x, top_20['veces_primer_articulo'], color='skyblue')
plt.title('Los 20 principales articulos que la gente pone primero en sus carritos')
plt.xlabel('ID- Nombre')
plt.ylabel('Veces_primer_articulo')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar estos valores hará que  quede aun mas clara la distribucion.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones. Se muestran los 20 articulos fueron agregados primero al carrito. Banana es el primer articulo que se agrega seguido de Bolsa de bananas organicas. Al parecer primero agregan sus frutas y verduras como primera entrada en el pedido.

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# 1.- Conclusion Descripcion de los datos:
#     En este apartado se realizo una exploracioón de como se encontraban los 5 archivos que se utilizaron en este proyecto, se conocio el giro del negocio y se tuvo una nocion de los datos que se iban a tratar. ya con esta exploracion se comenzo en cargar los 5 dataframes y se comenzo a examinar cada conjunto de datos para conocer mas su contenido, se encontro que algunos df contenian datos perdidos y valores duplicados.
#
#
# 2.- Conclusion procesamiento de datos:
#     Despues de que ya tuvimos una nocion de los datos y archivos que vamos a tratar se comenzo a procesarlos o limpiarlos para dejarlos lo mas claro posible para de esta forma obtener mejores resultados en la etapa de analisis de datos. Se comenzo a realizar la limpieza de los datos eliminando los valores ausentes que no tenian ningun valor para los cuestionarios finales al igual algunos valores ausentes fueron reemplazados por datos mas coherentes para llenar esos espacios vacios. Por ultimo se eliminaron los duplicados de filas que al explorar los datos se encontraron con que si era informacion duplicada.
#
#
# 3.- Conclusion Analisis de datos:
#     En esta etapa final se comenzo en realizar el analisis de los datos para obtener respuestas a preguntas especificas por el cliente se usaron diferentes herramientas para agrupar, segmentar y presentar la informacion valiosa para la toma de deciciones en este caso que los clientes consumieran o compraran mas productos, esto explorando algunas preguntas como sabiando los articulos mas vendidos, a que hora y dia de la semana la gente compraba mas productos, cuanto tiempo la gente esperaba para poder realizar otro pedido cual era el lapso de tiempo en lo que esto sucediera, al igual que conocer el numero de articulos que llevan en promedio en su carrito en cada pedido, conociendo tambien la proporcion de productos que se vuelven a colocar primero en los carritos.
#
#     Al final de este analisis de datos se llega a la conclusion que con este analisis el dueño del negocio conoce los habitos y forma de comprar de sus clientes. Para poder afrontar de mejor manera las oportunidades y necesidades del cliente. Teniendo siempre stock de los productos que mas se conocen y poder crear o colocar nuevos productos que con base al analisis les resulte atractivo al publico para seguir comprando, teniendo siempre promociones o descuentos para poder competir con la competencia.
#
# </div>

# %% [markdown]
# #Se me hizo muy largo y tardado este proyecto  ya que me encontraba con dificultades para entender bien lo que se queria hacer ya que venian un poco diferente las traducciones en el proyecto dentro del jupiter y fuera de el. Al ir avanzando en cada paso se me fue dificultando. El paso 3 fue el mas complicado, ya que tuve que repasar de nuevo todo lo aprendido en el Sprint 1,2, y 3. La parte del analisis y tener que saber que funciones o como obtener los resultados se me hizo complicado.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda realizar una conclusion general orientada al cliente. Esta debe contener todo lo que se hizo en el proyecto de forma enumerada o items.
#
# Desde la carga e importacion, pasando por los cambios realizado (Y el porque de esas decisiones). Agregando lo que se hizo en cada seccion a modo resumen y las conclusiones del  trabajo.
#
# Sirve como resumen de lo realizado en cada proyecto.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, excelente conclusion general.
#
# </div>
